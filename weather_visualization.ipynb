# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
weather = pd.read_csv('Test.csv')

# %%
weather.head()
# Out:
#     date_time  humidity  wind_speed  visibility_in_miles  temperature  \
# 0  18-05-2017      63.0         1.0                  4.0       285.15
# 1  18-05-2017      63.0         1.0                  4.0       285.15
# 2  18-05-2017      56.0         1.0                  1.0       285.15
# 3  18-05-2017      56.0         1.0                  2.0       284.79
# 4  18-05-2017      56.0         1.0                  1.0       284.79
#
#   weather_type      weather_description
# 0         Rain            moderate rain
# 1         Mist                     mist
# 2      Drizzle  light intensity drizzle
# 3         Rain     heavy intensity rain
# 4         Mist                     mist

# %%
sns.displot(weather['temperature'])

# %%
sns.jointplot(x=weather['humidity'], y=weather['wind_speed'])

# %%
sns.stripplot(x=weather['weather_type'],y=weather['humidity'])
# Out:
# <AxesSubplot:xlabel='weather_type', ylabel='humidity'>

# %%
sns.boxplot(x=weather['visibility_in_miles'],y=weather['humidity'])
# Out:
# <AxesSubplot:xlabel='visibility_in_miles', ylabel='humidity'>

# %%
sns.countplot(y=weather['weather_type'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='weather_type'>
